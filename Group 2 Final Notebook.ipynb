# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# Question 1: For Each Borough in New York City, What is The Number of Crimes Belonging to Each Offence Level?

# %%
#import data files
cleaned_data_path = Path("clean_data/cleaned_nyc_crime_data.csv")

# %%
#Read nyc cleaned crime data 
nyc_clean_df = pd.read_csv(cleaned_data_path)
nyc_clean_df.head()
# Out:
#   offence level   borough suspect age group suspect race suspect sex  \
# 0     VIOLATION  BROOKLYN             45-64        WHITE           M
# 1   MISDEMEANOR  BROOKLYN           Unknown      Unknown     Unknown
# 2     VIOLATION  BROOKLYN             25-44        BLACK           M
# 3   MISDEMEANOR  BROOKLYN             25-44        BLACK     Unknown
# 4   MISDEMEANOR  BROOKLYN             45-64        WHITE           M
#
#     Latitude  Longitude                  Lat_Lon victim age group victim race  \
# 0  40.621708 -74.000593  (40.621708, -74.000593)            25-44       WHITE
# 1  40.618867 -74.021057  (40.618867, -74.021057)            25-44       WHITE
# 2  40.705035 -73.939373  (40.705035, -73.939373)            45-64       BLACK
# 3  40.700294 -73.990838  (40.700294, -73.990838)            25-44       BLACK
# 4  40.622093 -73.998140   (40.622093, -73.99814)          Unknown     UNKNOWN
#
#   victim sex      pop
# 0          F  2590516
# 1          M  2590516
# ...

# %%
#Filter dataset to find counts of crimes (broken down by offence level) for each borough
borough_breakdown = nyc_clean_df.groupby(["borough"])["offence level"].value_counts()
borough_breakdown
# Out:
# borough        offence level
# BRONX          MISDEMEANOR      53770
#                FELONY           37321
#                VIOLATION        18940
# BROOKLYN       MISDEMEANOR      71012
#                FELONY           48335
#                VIOLATION        25019
# MANHATTAN      MISDEMEANOR      70058
#                FELONY           44149
#                VIOLATION        16765
# QUEENS         MISDEMEANOR      57231
#                FELONY           37357
#                VIOLATION        17660
# STATEN ISLAND  MISDEMEANOR      11637
#                FELONY            5734
#                VIOLATION         4690
# Name: count, dtype: int64

# %%
#Create and display dataframe 
borough_summary = pd.DataFrame({"Crime Counts": borough_breakdown})
borough_summary
# Out:
#                              Crime Counts
# borough       offence level
# BRONX         MISDEMEANOR           53770
#               FELONY                37321
#               VIOLATION             18940
# BROOKLYN      MISDEMEANOR           71012
#               FELONY                48335
#               VIOLATION             25019
# MANHATTAN     MISDEMEANOR           70058
#               FELONY                44149
#               VIOLATION             16765
# QUEENS        MISDEMEANOR           57231
#               FELONY                37357
#               VIOLATION             17660
# STATEN ISLAND MISDEMEANOR           11637
#               FELONY                 5734
#               VIOLATION              4690

# %%
#filter data set to show only misdemeanor
borough_misdemeanor = nyc_clean_df.loc[(nyc_clean_df["offence level"] == "MISDEMEANOR"), :]
borough_misdemeanor
# Out:
#        offence level    borough suspect age group              suspect race  \
# 1        MISDEMEANOR   BROOKLYN           Unknown                   Unknown
# 3        MISDEMEANOR   BROOKLYN             25-44                     BLACK
# 4        MISDEMEANOR   BROOKLYN             45-64                     WHITE
# 7        MISDEMEANOR   BROOKLYN           Unknown                   Unknown
# 9        MISDEMEANOR   BROOKLYN             25-44  ASIAN / PACIFIC ISLANDER
# ...              ...        ...               ...                       ...
# 519667   MISDEMEANOR  MANHATTAN             25-44                     BLACK
# 519671   MISDEMEANOR  MANHATTAN             25-44                     BLACK
# 519674   MISDEMEANOR  MANHATTAN           Unknown                   Unknown
# 519675   MISDEMEANOR  MANHATTAN             25-44            WHITE HISPANIC
# 519677   MISDEMEANOR  MANHATTAN           Unknown                     BLACK
#
#        suspect sex   Latitude  Longitude  \
# ...

# %%
#Find counts of misdemeanor in each borough
group_bor_mis = borough_misdemeanor.groupby(["borough"])["offence level"].count()
group_bor_mis
# Out:
# borough
# BRONX            53770
# BROOKLYN         71012
# MANHATTAN        70058
# QUEENS           57231
# STATEN ISLAND    11637
# Name: offence level, dtype: int64

# %%
#filter data set to show only Felony
borough_felony = nyc_clean_df.loc[(nyc_clean_df["offence level"] == "FELONY"), :]
borough_felony
# Out:
#        offence level    borough suspect age group              suspect race  \
# 6             FELONY   BROOKLYN           Unknown                   Unknown
# 8             FELONY   BROOKLYN             25-44                     BLACK
# 18            FELONY   BROOKLYN           Unknown                   Unknown
# 19            FELONY   BROOKLYN             18-24                     BLACK
# 25            FELONY   BROOKLYN           Unknown            WHITE HISPANIC
# ...              ...        ...               ...                       ...
# 519668        FELONY  MANHATTAN           Unknown                   Unknown
# 519670        FELONY  MANHATTAN           Unknown  ASIAN / PACIFIC ISLANDER
# 519672        FELONY  MANHATTAN           Unknown                   Unknown
# 519673        FELONY  MANHATTAN           Unknown            WHITE HISPANIC
# 519676        FELONY  MANHATTAN           Unknown                   Unknown
#
#        suspect sex   Latitude  Longitude  \
# ...

# %%
#Find counts of felony in each borough
group_bor_fel = borough_felony.groupby(["borough"])["offence level"].count()
group_bor_fel
# Out:
# borough
# BRONX            37321
# BROOKLYN         48335
# MANHATTAN        44149
# QUEENS           37357
# STATEN ISLAND     5734
# Name: offence level, dtype: int64

# %%
#filter data set to show only violation
borough_violation = nyc_clean_df.loc[(nyc_clean_df["offence level"] == "VIOLATION"), :]
borough_violation
# Out:
#        offence level    borough suspect age group    suspect race suspect sex  \
# 0          VIOLATION   BROOKLYN             45-64           WHITE           M
# 2          VIOLATION   BROOKLYN             25-44           BLACK           M
# 5          VIOLATION   BROOKLYN             45-64           WHITE           M
# 10         VIOLATION   BROOKLYN           Unknown         Unknown     Unknown
# 11         VIOLATION   BROOKLYN           Unknown         Unknown     Unknown
# ...              ...        ...               ...             ...         ...
# 519650     VIOLATION  MANHATTAN           Unknown         Unknown     Unknown
# 519657     VIOLATION  MANHATTAN           Unknown         Unknown           M
# 519660     VIOLATION  MANHATTAN           Unknown  WHITE HISPANIC           F
# 519666     VIOLATION  MANHATTAN           Unknown           BLACK     Unknown
# 519669     VIOLATION  MANHATTAN             25-44           WHITE           M
#
# ...

# %%
#Find counts of violation in each borough
group_bor_vio = borough_violation.groupby(["borough"])["offence level"].count()
group_bor_vio
# Out:
# borough
# BRONX            18940
# BROOKLYN         25019
# MANHATTAN        16765
# QUEENS           17660
# STATEN ISLAND     4690
# Name: offence level, dtype: int64

# %%
#Create and display dataframe 
borough_offence_summary = pd.DataFrame({"Misdemeanor Count": group_bor_mis, "Felony Count": group_bor_fel, "Violation Count": group_bor_vio})
borough_offence_summary
# Out:
#                Misdemeanor Count  Felony Count  Violation Count
# borough
# BRONX                      53770         37321            18940
# BROOKLYN                   71012         48335            25019
# MANHATTAN                  70058         44149            16765
# QUEENS                     57231         37357            17660
# STATEN ISLAND              11637          5734             4690

# %%
#Add total column to dataframe
total_count = borough_offence_summary["Misdemeanor Count"]+borough_offence_summary["Felony Count"]+borough_offence_summary["Violation Count"] 
borough_offence_summary["Total Count"] = total_count
borough_offence_summary
# Out:
#                Misdemeanor Count  Felony Count  Violation Count  Total Count
# borough
# BRONX                      53770         37321            18940       110031
# BROOKLYN                   71012         48335            25019       144366
# MANHATTAN                  70058         44149            16765       130972
# QUEENS                     57231         37357            17660       112248
# STATEN ISLAND              11637          5734             4690        22061

# %%
#Sort dataframe from highest to lowest
sorted_summary = borough_offence_summary.sort_values("Total Count", ascending=False)
sorted_summary
# Out:
#                Misdemeanor Count  Felony Count  Violation Count  Total Count
# borough
# BROOKLYN                   71012         48335            25019       144366
# MANHATTAN                  70058         44149            16765       130972
# QUEENS                     57231         37357            17660       112248
# BRONX                      53770         37321            18940       110031
# STATEN ISLAND              11637          5734             4690        22061

# %%
#Reindex dataframe and place total count first for graph
data_df = sorted_summary.reindex(columns=['Total Count', 'Misdemeanor Count', 'Felony Count', 'Violation Count'])
data_df.reset_index(drop=True, inplace=True)
data_df
# Out:
#    Total Count  Misdemeanor Count  Felony Count  Violation Count
# 0       144366              71012         48335            25019
# 1       130972              70058         44149            16765
# 2       112248              57231         37357            17660
# 3       110031              53770         37321            18940
# 4        22061              11637          5734             4690

# %%
#Re add borough column
borough = ['BROOKLYN', 'MANHATTAN', 'QUEENS', 'BRONX', 'STATEN ISLAND']
#FINAL DATAFRAME FOR GRAPHS
data_df.insert(0, 'borough', borough)
data_df
# Out:
#          borough  Total Count  Misdemeanor Count  Felony Count  \
# 0       BROOKLYN       144366              71012         48335
# 1      MANHATTAN       130972              70058         44149
# 2         QUEENS       112248              57231         37357
# 3          BRONX       110031              53770         37321
# 4  STATEN ISLAND        22061              11637          5734
#
#    Violation Count
# 0            25019
# 1            16765
# 2            17660
# 3            18940
# 4             4690

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = data_df.plot(kind="bar", figsize=(8,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(data_df["borough"], rotation=45)
plt.title('Crime count by level of offence for each borough in NYC')
plt.ylabel('Crime Count')
plt.xlabel('Boroughs')
plt.show()
plt.tight_layout()

# %%
#map
coordinates = {
    "latitude": [40.650002, 40.776676, 40.742054, 40.837048, 40.579021],
    "longitude": [-73.949997, -73.971321, -73.769417, -73.865433, -74.151535],
    "borough": ["Brooklyn", "Manhattan", "Queens", "Bronx", "Staten Island"],
    "Crime Count": [144366, 130972, 112248, 110031, 22061]
}

# %%
#create dataframe
coordinates_df = pd.DataFrame(coordinates)

# %%
#plot map 
map_plot = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Crime Count",
    scale = 0.2,
    color = "borough"
)

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (borough,Crime Count)

# %% [markdown]
# Analysis:
# Looking at the graph above, all boroughs apart from staten-island have similar total crime counts (between 115,000 - 140,000) with Brooklyn having the highest count. Breaking down the level of offence categories (misdemeanour, felony and violation). In each borough misdemeanour counts are the most common crime (also the least serious offence), then felony, and violation (most serious offence). Comparing the two highest boroughs Brooklyn and Manhattan, they both have similar counts for misdemeanour and felony offences, however Brooklyn’s violation count is significantly higher. From this summary it can be suggested that Brooklyn is the most common place for a crime to take place in NYC and is the most violent (based on offence level counts).

# %% [markdown]
# Q2 What age group is most likely to commit a crime and be victim to a crime for each level of offense?

# %%
#import data files
nyc_cleanedcrimedata_path = "clean_data/cleaned_nyc_crime_data.csv"

# %%
#Read nyc crime data 
nyc_cleanedcrimedata_df = pd.read_csv(nyc_cleanedcrimedata_path)
nyc_cleanedcrimedata_df.head()
# Out:
#   offence level   borough suspect age group suspect race suspect sex  \
# 0     VIOLATION  BROOKLYN             45-64        WHITE           M
# 1   MISDEMEANOR  BROOKLYN           Unknown      Unknown     Unknown
# 2     VIOLATION  BROOKLYN             25-44        BLACK           M
# 3   MISDEMEANOR  BROOKLYN             25-44        BLACK     Unknown
# 4   MISDEMEANOR  BROOKLYN             45-64        WHITE           M
#
#     Latitude  Longitude                  Lat_Lon victim age group victim race  \
# 0  40.621708 -74.000593  (40.621708, -74.000593)            25-44       WHITE
# 1  40.618867 -74.021057  (40.618867, -74.021057)            25-44       WHITE
# 2  40.705035 -73.939373  (40.705035, -73.939373)            45-64       BLACK
# 3  40.700294 -73.990838  (40.700294, -73.990838)            25-44       BLACK
# 4  40.622093 -73.998140   (40.622093, -73.99814)          Unknown     UNKNOWN
#
#   victim sex      pop
# 0          F  2590516
# 1          M  2590516
# ...

# %%
nyc_cleanedcrimedata_df=nyc_cleanedcrimedata_df.rename(columns={"pop":"population"})
nyc_cleanedcrimedata_df.head()
# Out:
#   offence level   borough suspect age group suspect race suspect sex  \
# 0     VIOLATION  BROOKLYN             45-64        WHITE           M
# 1   MISDEMEANOR  BROOKLYN           Unknown      Unknown     Unknown
# 2     VIOLATION  BROOKLYN             25-44        BLACK           M
# 3   MISDEMEANOR  BROOKLYN             25-44        BLACK     Unknown
# 4   MISDEMEANOR  BROOKLYN             45-64        WHITE           M
#
#     Latitude  Longitude                  Lat_Lon victim age group victim race  \
# 0  40.621708 -74.000593  (40.621708, -74.000593)            25-44       WHITE
# 1  40.618867 -74.021057  (40.618867, -74.021057)            25-44       WHITE
# 2  40.705035 -73.939373  (40.705035, -73.939373)            45-64       BLACK
# 3  40.700294 -73.990838  (40.700294, -73.990838)            25-44       BLACK
# 4  40.622093 -73.998140   (40.622093, -73.99814)          Unknown     UNKNOWN
#
#   victim sex  population
# 0          F     2590516
# 1          M     2590516
# ...

# %%
#groupby  commited crime by Perpetractor's age and level of offence
grouped_Perpetrator=nyc_cleanedcrimedata_df.groupby(["suspect age group","offence level"]).size().reset_index(name='count')
grouped_Perpetrator.head(20)
# Out:
#    suspect age group offence level   count
# 0              18-24        FELONY   12684
# 1              18-24   MISDEMEANOR   16157
# 2              18-24     VIOLATION    5498
# 3              25-44        FELONY   40851
# 4              25-44   MISDEMEANOR   66982
# 5              25-44     VIOLATION   25499
# 6              45-64        FELONY   11857
# 7              45-64   MISDEMEANOR   22385
# 8              45-64     VIOLATION   11630
# 9                65+        FELONY     899
# 10               65+   MISDEMEANOR    2000
# 11               65+     VIOLATION    2099
# 12               <18        FELONY    2688
# 13               <18   MISDEMEANOR    4402
# 14               <18     VIOLATION    2384
# 15           Unknown        FELONY  103917
# 16           Unknown   MISDEMEANOR  151782
# 17           Unknown     VIOLATION   35964

# %%
#Pivot the dataframe for better visualisation

Perpetratorpivot_df = grouped_Perpetrator.pivot(index='suspect age group', columns='offence level', values='count')
Perpetratorpivot_df.head(6)
# Out:
# offence level      FELONY  MISDEMEANOR  VIOLATION
# suspect age group
# 18-24               12684        16157       5498
# 25-44               40851        66982      25499
# 45-64               11857        22385      11630
# 65+                   899         2000       2099
# <18                  2688         4402       2384
# Unknown            103917       151782      35964

# %%
# Plotting the grouped bar chart
Perpetratorpivot_df.plot(kind='bar', figsize=(10, 6), width=0.8)
plt.title("Counts of Each Offense Level for Suspect's Age Group")
plt.xlabel("Suspect Age Groups")
plt.ylabel("Count")
plt.legend(title="Offense Level", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Analysis:
# Most common offence level for across all suspect age group is Misdemeanor follwed by Felony and Violation.
# The age group 25-44 has the highest counts across all offense levels, indicating that this age group is most frequently associated with reported incidents.
# The Unknown category for suspect age groups seems to have significantly higher counts for all offense levels, suggesting that the age information is missing or unspecified in many cases.
# The <18 age group has relatively lower counts compared to the 25-44 age group but still shows a notable presence.
#
# Each offense level has a different distribution across age groups, highlighting the variations in the involvement of different age groups in various types of offenses. Further analysis could explore the reasons behind the patterns observed, such as potential trends or correlations between age groups and types of offenses.

# %%
#groupby  commited crime by Victim's age and level of offence
grouped_Victim=nyc_cleanedcrimedata_df.groupby(["victim age group","offence level"]).size().reset_index(name='count')
grouped_Victim.head(20)
# Out:
#    victim age group offence level  count
# 0             18-24        FELONY  15327
# 1             18-24   MISDEMEANOR  20566
# 2             18-24     VIOLATION   7909
# 3             25-44        FELONY  62405
# 4             25-44   MISDEMEANOR  84301
# 5             25-44     VIOLATION  38365
# 6             45-64        FELONY  31604
# 7             45-64   MISDEMEANOR  43549
# 8             45-64     VIOLATION  23491
# 9               65+        FELONY  10715
# 10              65+   MISDEMEANOR   9212
# 11              65+     VIOLATION   5813
# 12              <18        FELONY   4737
# 13              <18   MISDEMEANOR   9626
# 14              <18     VIOLATION   3726
# 15          Unknown        FELONY  48108
# 16          Unknown   MISDEMEANOR  96454
# 17          Unknown     VIOLATION   3770

# %%
#Pivot the dataframe for better visualisation
Victimpivot_df = grouped_Victim.pivot(index='victim age group', columns='offence level', values='count')
Victimpivot_df.head(6)
# Out:
# offence level     FELONY  MISDEMEANOR  VIOLATION
# victim age group
# 18-24              15327        20566       7909
# 25-44              62405        84301      38365
# 45-64              31604        43549      23491
# 65+                10715         9212       5813
# <18                 4737         9626       3726
# Unknown            48108        96454       3770

# %%
# Plotting the victims grouped bar chart
Victimpivot_df.plot(kind='bar', figsize=(10, 6), width=0.8)
plt.title("Counts of Each Offense Level for Victim's Age Group")
plt.xlabel("Victim Age Groups")
plt.ylabel("Count")
plt.legend(title="Offense Level", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Analysis:
# Similar to the suspect age group analysis, the 25-44 age group has the highest counts across all offense levels, indicating that this age group is most at risk. The Unknown category for victim age groups seems to have relatively high counts, suggesting that age information for victims is missing or unspecified in many cases. The <18 age group shows notable counts, particularly for MISDEMEANOR offenses.

# %% [markdown]
# Question 3: What Race Group Is Most Likely To Commit A Crime & Be A Victim To A Crime For Each Offence Level In Each Borough?

# %%
# This part will look at the suspect race data
data = "clean_data/cleaned_nyc_crime_data.csv"

data_df = pd.read_csv(data)
data_df
# Out:
#        offence level    borough suspect age group    suspect race suspect sex  \
# 0          VIOLATION   BROOKLYN             45-64           WHITE           M
# 1        MISDEMEANOR   BROOKLYN           Unknown         Unknown     Unknown
# 2          VIOLATION   BROOKLYN             25-44           BLACK           M
# 3        MISDEMEANOR   BROOKLYN             25-44           BLACK     Unknown
# 4        MISDEMEANOR   BROOKLYN             45-64           WHITE           M
# ...              ...        ...               ...             ...         ...
# 519673        FELONY  MANHATTAN           Unknown  WHITE HISPANIC           M
# 519674   MISDEMEANOR  MANHATTAN           Unknown         Unknown     Unknown
# 519675   MISDEMEANOR  MANHATTAN             25-44  WHITE HISPANIC           M
# 519676        FELONY  MANHATTAN           Unknown         Unknown           M
# 519677   MISDEMEANOR  MANHATTAN           Unknown           BLACK           F
#
# ...

# %%
# Dropping na values in suspect race column
suspect_data_df = data_df.dropna(subset = ["suspect race"])
suspect_data_df = suspect_data_df[["offence level","borough","suspect race"]]
suspect_data_df = suspect_data_df.rename(columns={"offence level":"level"})
suspect_data_df
# Out:
#               level    borough    suspect race
# 0         VIOLATION   BROOKLYN           WHITE
# 1       MISDEMEANOR   BROOKLYN         Unknown
# 2         VIOLATION   BROOKLYN           BLACK
# 3       MISDEMEANOR   BROOKLYN           BLACK
# 4       MISDEMEANOR   BROOKLYN           WHITE
# ...             ...        ...             ...
# 519673       FELONY  MANHATTAN  WHITE HISPANIC
# 519674  MISDEMEANOR  MANHATTAN         Unknown
# 519675  MISDEMEANOR  MANHATTAN  WHITE HISPANIC
# 519676       FELONY  MANHATTAN         Unknown
# 519677  MISDEMEANOR  MANHATTAN           BLACK
#
# [519678 rows x 3 columns]

# %%
# Making pandas series for each suspect race
black = suspect_data_df[suspect_data_df["suspect race"] == "BLACK"]
whis = suspect_data_df[suspect_data_df["suspect race"] == "WHITE HISPANIC"]
white = suspect_data_df[suspect_data_df["suspect race"] == "WHITE"]
bhis = suspect_data_df[suspect_data_df["suspect race"] == "BLACK HISPANIC"]
aspac = suspect_data_df[suspect_data_df["suspect race"] == "ASIAN / PACIFIC ISLANDER"]
inala = suspect_data_df[suspect_data_df["suspect race"] == "AMERICAN INDIAN/ALASKAN NATIVE"]

# Segregating each suspect race by the borough the crimes occurred in
black_bo = black.groupby(["borough"])
whis_bo = whis.groupby(["borough"])
white_bo = white.groupby(["borough"])
bhis_bo = bhis.groupby(["borough"])
aspac_bo = aspac.groupby(["borough"])
inala_bo = inala.groupby(["borough"])

# %%
# Counting all the crime levels within each borough
black_levelcounts = black_bo["level"].value_counts()
whis_levelcounts = whis_bo["level"].value_counts()
white_levelcounts = white_bo["level"].value_counts()
bhis_levelcounts = bhis_bo["level"].value_counts()
aspac_levelcounts = aspac_bo["level"].value_counts()
inala_levelcounts = inala_bo["level"].value_counts()

# Forming a dictionary to store everything
suspect_dict = {"Black" : black_levelcounts,
                "White Hispanic" : whis_levelcounts,
                "White" : white_levelcounts,
                "Black Hispanic" : bhis_levelcounts,
                "Asian/Pacific Islander" : aspac_levelcounts,
                "American Indian/Alaskan Native" : inala_levelcounts}
#Forming the dataframe
final_sus_df = pd.DataFrame(suspect_dict)
final_sus_df
# Out:
#                            Black  White Hispanic  White  Black Hispanic  \
# borough       level
# BRONX         FELONY       10259            5510    563            3036
#               MISDEMEANOR  15836            9491   1311            4630
#               VIOLATION     7275            4109    746            1767
# BROOKLYN      FELONY       15643            3994   2655            1006
#               MISDEMEANOR  21449            6325   5861            1533
#               VIOLATION    11821            2637   2982             665
# MANHATTAN     FELONY       13210            4689   2632            1847
#               MISDEMEANOR  22974            9669   6641            3635
#               VIOLATION     6494            2669   2282            1030
# QUEENS        FELONY        7763            5241   1893             886
#               MISDEMEANOR  11509            8261   3924            1150
#               VIOLATION     4735            3281   2166             417
# ...

# %%
sus_plot = final_sus_df.plot(kind="bar",stacked=True,title="Number of Crimes Occurring for Each Offence Level In Each Borough for Each Suspect's Race",xlabel="Borough, Offence Level",ylabel="Number of Crimes")
sus_plot.legend(bbox_to_anchor=(1.0, 1.0))
plt.savefig("Suspect Race Graph.png",bbox_inches="tight")

# %% [markdown]
# Analysis:
# Examining the suspect graph above, it can be determined that for all the crimes that occur in each borough, the proportion of suspect races is different, but are proportional to the race distribution of the population within New York City. Within all boroughs in New York City, the greatest proportion of suspect races in all offence levels belong to Black suspects. However, White suspects commit the most number of violations within Staten Island. For the majority of the other data points, the second-most populous suspect race group for most offence levels and boroughs is White Hispanic. However, within Brooklyn, where both White and White Hispanic suspects equally commit the second most number of misdemeanors, and where White suspects are second when it comes to violations. Within Manhattan, White and White Hispanic suspects commit the second-most number of violations. Within Staten Island, White suspects are second to Black suspects when it comes to felonies and misdemeanors. While race population distribution would play a role in the data observed, more socio-cultural influences may be at play, but further external analysis would need to be done. This analysis would have to observe employment rates, average income, education statistics as well as other socio-cultural factors to come to a conclusion.

# %%
# This part will look at the victim data
# Dropping na values in victim race column
victim_data_df = data_df.dropna(subset = ["victim race"])
victim_data_df = victim_data_df[["offence level","borough","victim race"]]
victim_data_df = victim_data_df.rename(columns={"offence level":"level"})
victim_data_df
# Out:
#               level    borough     victim race
# 0         VIOLATION   BROOKLYN           WHITE
# 1       MISDEMEANOR   BROOKLYN           WHITE
# 2         VIOLATION   BROOKLYN           BLACK
# 3       MISDEMEANOR   BROOKLYN           BLACK
# 4       MISDEMEANOR   BROOKLYN         UNKNOWN
# ...             ...        ...             ...
# 519673       FELONY  MANHATTAN         UNKNOWN
# 519674  MISDEMEANOR  MANHATTAN         UNKNOWN
# 519675  MISDEMEANOR  MANHATTAN  WHITE HISPANIC
# 519676       FELONY  MANHATTAN         UNKNOWN
# 519677  MISDEMEANOR  MANHATTAN           BLACK
#
# [519678 rows x 3 columns]

# %%
# Making pandas series for each victim race
blackv = victim_data_df[victim_data_df["victim race"] == "BLACK"]
whisv = victim_data_df[victim_data_df["victim race"] == "WHITE HISPANIC"]
whitev = victim_data_df[victim_data_df["victim race"] == "WHITE"]
bhisv = victim_data_df[victim_data_df["victim race"] == "BLACK HISPANIC"]
aspacv = victim_data_df[victim_data_df["victim race"] == "ASIAN / PACIFIC ISLANDER"]
inalav = victim_data_df[victim_data_df["victim race"] == "AMERICAN INDIAN/ALASKAN NATIVE"]

# Segregating each victim race by the borough the crimes occurred in
black_bov = blackv.groupby(["borough"])
whis_bov = whisv.groupby(["borough"])
white_bov = whitev.groupby(["borough"])
bhis_bov = bhisv.groupby(["borough"])
aspac_bov = aspacv.groupby(["borough"])
inala_bov = inalav.groupby(["borough"])

# %%
# Counting all the crime levels within each borough
vblack_levelcounts = black_bov["level"].value_counts()
vwhis_levelcounts = whis_bov["level"].value_counts()
vwhite_levelcounts = white_bov["level"].value_counts()
vbhis_levelcounts = bhis_bov["level"].value_counts()
vaspac_levelcounts = aspac_bov["level"].value_counts()
vinala_levelcounts = inala_bov["level"].value_counts()

# Forming a dictionary to store everything
victim_dict = {"Black" : vblack_levelcounts,
                "White Hispanic" : vwhis_levelcounts,
                "White" : vwhite_levelcounts,
                "Black Hispanic" : vbhis_levelcounts,
                "Asian/Pacific Islander" : vaspac_levelcounts,
                "American Indian/Alaskan Native" : vinala_levelcounts}
#Forming the dataframe
final_vic_df = pd.DataFrame(victim_dict)
final_vic_df
# Out:
#                            Black  White Hispanic  White  Black Hispanic  \
# borough       level
# BRONX         FELONY        9707            9709   2032            3883
#               MISDEMEANOR  14451           12688   2448            4754
#               VIOLATION     7458            6069   1224            2020
# BROOKLYN      FELONY       14449            6147   8553            1135
#               MISDEMEANOR  22349            8362  11271            1482
#               VIOLATION    12557            3868   4558             667
# MANHATTAN     FELONY        6443            5739  10103            1736
#               MISDEMEANOR  10059            7722   9082            2289
#               VIOLATION     5456            3719   3737            1092
# QUEENS        FELONY        6241            7862   5254             729
#               MISDEMEANOR   9902           11126   7153             941
#               VIOLATION     5097            4507   3180             389
# ...

# %%
vic_plot = final_vic_df.plot(kind="bar",stacked=True,title="Number of Crimes Occurring for Each Offence Level In Each Borough for Each Victim's Race",xlabel="Borough, Offence Level",ylabel="Number of Crimes")
vic_plot.legend(bbox_to_anchor=(1.0, 1.0))
plt.savefig("Victim Race Graph.png",bbox_inches="tight")

# %% [markdown]
# Analysis:
# Examining the victim graph above, it can be determined that for all the crimes that occur in each borough, the proportion of victim races is different, but are proportional to the race distribution of the population within New York City. Within the Bronx, the greatest proportion of victim races belong to Black and White Hispanic victims. Within Brooklyn, the vast majority of victims across all offence levels are Black. Within Manhattan and Staten Island, the vast majority of victims in all offence levels are White. Within Queens, the number of victims across all offence levels are roughly equal between Asians/Pacific Islanders, White Hispanic and Black victims. Across all boroughs and offence levels, American Indian/Alaskan Natives make up a significantly miniscule proportion of victims, due to their relatively miniscule population numbers as compared to the rest of the races living within New York City.

# %% [markdown]
# Question 4: What is the per capita ratio of crimes commited in each borough?

# %%
#group total crimes per borough
boroughcrime_count=nyc_cleanedcrimedata_df.groupby(['borough','population']).size().reset_index(name='totalcrimes')
boroughcrime_count.head()
# Out:
#          borough  population  totalcrimes
# 0          BRONX     1379946       110031
# 1       BROOKLYN     2590516       144366
# 2      MANHATTAN     1596273       130972
# 3         QUEENS     2278029       112248
# 4  STATEN ISLAND      491133        22061

# %%
#calculate per capita ration for crime commited in each borough
boroughcrime_count['percapita_ratio']=boroughcrime_count['totalcrimes']/boroughcrime_count['population']*100

boroughcrime_count.head()
# Out:
#          borough  population  totalcrimes  percapita_ratio
# 0          BRONX     1379946       110031         7.973573
# 1       BROOKLYN     2590516       144366         5.572867
# 2      MANHATTAN     1596273       130972         8.204862
# 3         QUEENS     2278029       112248         4.927418
# 4  STATEN ISLAND      491133        22061         4.491859

# %%
# create a DataFrame

boroughcrime_count_df=pd.DataFrame(boroughcrime_count)

#plot percapita_ratio for each borough



x_axis = np.arange(len(boroughcrime_count_df['borough']))

 # Create a bar chart based upon the above data
    
bar = plt.bar(x_axis, boroughcrime_count_df['percapita_ratio'], width=0.5, label='Per Capita Ratio')

# Create the ticks for our bar chart's x axis
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, boroughcrime_count_df['borough'])

# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)

# Set the limits of the y axis
plt.ylim(0, max(boroughcrime_count_df['percapita_ratio'])+2)

 # Give the chart a title, x label, and y label
plt.xlabel('Borough')
plt.ylabel('Per Capita Ratio')
plt.title('Comparison by Borough')

# ax.set_xticklabels(boroughcrime_count_df['borough'])
plt.legend()

plt.show()

# %% [markdown]
# Analysis:
# Manhattan has the highest per capita ratio, indicating a relatively higher rate of crimes per person compared to other boroughs (8.20%).
# Staten Island has the lowest per capita ratio, suggesting a relatively lower rate of crimes per person (4.49%).
# This question brings in a new set of data linking crime statistics to the general population.
# Results of comparison of crime numbers to a registered number of residential population (or taxpayer base) highlights anomalies, such as Manhattan ranking the highest.
# This can be either due to actual higher crime activity or  because one of the datasets not been compared in a meaningful way to the other.
# One possibility is that total population number here produces higher ratios as it does not include any transient populations, such as tourists or individuals with an address outside this specific borough.
# On a separate note, with the price of real estate in Manhattan, there is a likelihood that persons affected by crimes were not actually a resident but a service provider or employee.
# Therefore, the number of individuals affected by crimes may need to be further analysed whether they were living there or for work / visit.
